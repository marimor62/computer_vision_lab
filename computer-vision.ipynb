# %% [markdown]
# # Computer Vision Lab

# %% [markdown]
# ### 1. Ethical issues with computer vision applications

# %% [markdown]
# EX1: The ethical questions that haunt facial-recognition research, https://www.nature.com/articles/d41586-020-03187-3

# %% [markdown]
# EX2: Identifying ethical issues during the development of a computer vision based AmI systems https://www.academia.edu/3185285/Identifying_ethical_issues_during_the_development_of_a_computer_vision_based_AmI_system_A_case_study

# %% [markdown]
# In my opinion, the main ethical issues are: gathering facial images without consent o the people, racism, bias when using it
# for law or policial causes, and the vigillance or lack of privacity.

# %% [markdown]
# ### 2. Computer Vision Explorer

# %% [markdown]
# example 1: A family watch TV while sitting on a couch

# %%
#result:
# %matplotlib inline
from IPython.display import Image
Image('foto1.png')

# %% [markdown]
# example2: A grassy tree filled field with a lot of kites in the air.

# %%
Image('foto3.png')

# %% [markdown]
# example3: A full view of a home office with many computer screens.

# %%
Image('foto2.png')
